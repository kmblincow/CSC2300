# %% [markdown]
# <a href="https://colab.research.google.com/github/kmblincow/CSC2300/blob/main/Final_Project_Notebook_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color='orange'>**Before you do anything else, make a copy of this notebook in your personal drive by going to "File > Save a copy in Drive" !!!!**
# #**You should complete the final project using the copy you just made.**  </font>
#
#
# ---
#
#
#
# ---

# %% [markdown]
# #**CSC 2300 Final Project**
# Student Name:
# Dataset Selected:
# Brief Description of Dataset:

# %% [markdown]
# ---
# ##Code Set Up

# %%
#load packages
library(tidyverse)

# %%
#load your dataset
#(you should update this with the correct read_csv() command for your dataset and a more appropriate object name)
marbles <- readr::read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/main/data/2020/2020-06-02/marbles.csv')

glimpse(marbles)

# %% [markdown]
# ---
# ##Data Cleaning and Management

# %% [markdown]
# **Written explanation**
#
#
# *   What issues did you find in the dataset?
# *   What did you remove, fix, or transform?
# *   Why were these decisions necessary?

# %% [markdown]
# ---
# #Exploratory Data Analysis

# %% [markdown]
# **Written explanation**
#
#
# *   What patterns did you notice?
# *   What surprised you?
# *   What potential relationships emerged?

# %% [markdown]
# ---
# ##Research Question
# What is the final research question you are going to address?

# %% [markdown]
# ---
# ##Final Analysis

# %% [markdown]
# **Written explanation**
#
#
# *   What was your approach to answering your question?
# *   Why did you select this approach?

# %% [markdown]
# ---
# ##Key Findings

# %% [markdown]
# **Written explanation**
# *   What did you find?
# *   Why does it matter?
# *   What should a stakeholder do with this information?
