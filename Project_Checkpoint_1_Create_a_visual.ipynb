# %% [markdown]
# <a href="https://colab.research.google.com/github/kmblincow/CSC2300/blob/main/Project_Checkpoint_1_Create_a_visual.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color='orange'>**Before you do anything else, make a copy of this notebook in your personal drive by going to "File > Save a copy in Drive" !!!!**
# #**You should complete the project checkpoint using the copy you just made.**  </font>
#
#
# ---
#
#
#
# ---

# %% [markdown]
# #**Project Checkpoint 1 - Create a visual**
# <font color='deeppink'>*Double click this section and populate it with the information requested.*
#
# Student Name:
# Dataset Name:
# Date/Week of TidyTuesday Release:
# Brief Description of Dataset:
# Dataset Link:

# %% [markdown]
# ---
# ##Code Set Up

# %%
#load packages
library(tidyverse)

# %% [markdown]
# In the documentation for TidyTuesday datasets there is a section that provides code for accessing the data. I recommend using the "Read directly from GitHub" code as it integrates more easily with Google Colab.
#
# I have provided an example below, you should update the code with the information for your chosen dataaset.

# %%
#load your dataset (UPDATE with information for your chosen dataset)
exped_tidy <- readr::read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/main/data/2025/2025-01-21/exped_tidy.csv')

#take a look at the data
glimpse(exped_tidy)

# %% [markdown]
# ##Initial Data Thoughts
# <font color='deeppink'>*Provide a brief written description of the dataset. Include the dimensions (rows and columns), the variables, and identification of any potential data quality issues (e.g. missing values).*

# %% [markdown]
# DOUBLE CLICK HERE TO TYPE YOUR RESPONSE

# %% [markdown]
# ##Create a Visual
# <font color='deeppink'>*Create an original visualization using ggplot2 that helps reveal a pattern, trend, distribution, or relationship within the data.*
#
# The visualization does not need to answer a final research question. Its purpose is to help you explore the dataset and identify possible directions for further analysis.
#
# Be sure to include:
# *   informative title
# *   axis labels
# *   plotting elements that align with your variable types
# *   a short caption explaining what the visualization shows and why it is interesting

# %%
#INSERT GGPLOT2 CODE FOR YOUR VISUALIZATION HERE

# %% [markdown]
# ##Reflection
# <font color='deeppink'>*Write a reflection (approximately 250-400 words).*
#
# Your reflection should consider:
#
# *   What patterns, trends, or surprises did you notice in your exploration?
# *   What challenges or limitations did you encounter in the dataset?
# *   Propose three potential questions that could be investigated using this dataset.
# * Which of the three questions seems most interesting or feasible for your final project and why?

# %% [markdown]
# DOUBLE CLICK HERE TO TYPE YOUR RESPONSE

# %% [markdown]
# ---
#
# ##**Submitting Google Colab Assignments**
# For assignments where we will be using Google Colab, I will have you submit them by sharing a link to your Google Colab document. You will do this in the same way you share any google-universe documents.
#
#
# *   Name your notebook YourFirstAndLastName_Week1CodingTutorial by clicking on the notebook name in the top left corner of the screen and adjusting it accordingly (for example: JaneDoe_Week1CodingTutorial)
# *   Click "Share" in the upper right hand corner.
# *   Set your "General Access" settings to "Anyone with the link" is a "Viewer"
# *   Click "Copy link"
# *   Paste your link into a word document, and submit that as your assignment on Brightspace.
#
# I should be able to then see all of your work, try out your code, but won't be able to make any lasting changes to your notebook.
#
# **IMPORTANT!!! THIS WILL ONLY WORK IF YOU MADE A COPY OF THE ORIGINAL NOTEBOOK THAT I SHARED IN YOUR OWN DRIVE! OTHERWISE YOUR WORK WILL NOT BE SAVED AND I WILL NOT BE ABLE TO SEE WHAT YOU'VE DONE**
#
# Run all of the code above, add code where specified, and complete the steps above to submit this week's tutorial assignment.
